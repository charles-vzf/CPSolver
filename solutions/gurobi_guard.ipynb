# %% [markdown]
# # Gurobi CSP Solver
#
# Ce notebook utilise Gurobi pour résoudre les problèmes de satisfaction de contraintes (CSP) et trouver toutes les solutions possibles afin de vérifier les solutions obtenues par CPSolver.
#
# ## Installation et utilisation
#
# Pour installer les packages Julia nécessaires :
# ```julia
# import Pkg; Pkg.add(["JuMP", "Gurobi", "MathOptInterface"])
# ```
#
# Pour lancer le serveur Jupyter :
# ```bash
# cd /home/madoff/CPSolver && /home/madoff/venv/bin/jupyter notebook --no-browser --port=8888
# ```

# %%
# import Pkg; Pkg.add(["JuMP", "Gurobi", "MathOptInterface"])

# %%
# Configuration de l'environnement Gurobi AVANT l'import des packages
# Ces variables doivent être définies avant que Julia charge Gurobi

# Configuration de l'environnement Gurobi
# ENV["GUROBI_HOME"] = "/home/madoff/.julia/artifacts/11980007f4c80fcdcbdd8e7b8dafaa8657dcead9"
# ENV["GRB_LICENSE_FILE"] = "/home/madoff/.gurobi/gurobi.lic"

# Configuration pour éviter les problèmes de connectivité
# ENV["GRB_WLSACCESSID"] = "891e8c63-a77b-40dc-ba42-f8b6d8314067"
# ENV["GRB_WLSSECRET"] = "493b4494-24c0-407f-a7c2-75550d53c44d"
# ENV["GRB_LICENSEID"] = "2710287"

# println("GUROBI_HOME: ", ENV["GUROBI_HOME"])
# println("GRB_LICENSE_FILE: ", ENV["GRB_LICENSE_FILE"])
# println("GRB_WLSACCESSID: ", ENV["GRB_WLSACCESSID"])
# println("GRB_LICENSEID: ", ENV["GRB_LICENSEID"])

# %%
# Import des packages nécessaires
using JuMP
using Gurobi
using MathOptInterface
using Printf
using Graphs
using GraphPlot
using Plots
using DelimitedFiles

# %% [markdown]
# ## Structures de données

# %%
# Structures de données pour les instances CSP
struct CSPInstance
    name::String
    num_variables::Int
    domain_size::Int
    num_constraints::Int
    domains::Vector{Tuple{Int, Int, Int}}  # (var_id, min_val, max_val)
    constraints::Vector{Tuple{Int, Int, Vector{Tuple{Int, Int}}}}  # (var1, var2, allowed_pairs)
    
    function CSPInstance(name::String, num_variables::Int, domain_size::Int, num_constraints::Int,
                        domains::Vector{Tuple{Int, Int, Int}}, 
                        constraints::Vector{Tuple{Int, Int, Vector{Tuple{Int, Int}}}})
        new(name, num_variables, domain_size, num_constraints, domains, constraints)
    end
end

struct CSPSolution
    instance_name::String
    num_variables::Int
    domain_size::Int
    solutions::Vector{Dict{Int, Int}}  # Dict{var_id => value}
    solve_time::Float64
    num_nodes::Int
    gap::Float64
    
    function CSPSolution(instance_name::String, num_variables::Int, domain_size::Int,
                        solutions::Vector{Dict{Int, Int}}, solve_time::Float64, 
                        num_nodes::Int, gap::Float64)
        new(instance_name, num_variables, domain_size, solutions, solve_time, num_nodes, gap)
    end
end

# %% [markdown]
# ## Lecteur d'instances CSP

# %%
# Fonction de lecture d'instances CSP
function parse_csp_instance(filename::String)::CSPInstance
    """
    Parse une instance CSP au format standard.
    """
    name = basename(filename)
    
    open(filename, "r") do file
        lines = readlines(file)
        
        num_variables = 0
        domain_size = 0
        num_constraints = 0
        domains = Tuple{Int, Int, Int}[]
        constraints = Tuple{Int, Int, Vector{Tuple{Int, Int}}}[]
        
        line_idx = 1
        
        # Ignorer les commentaires au début
        while line_idx <= length(lines) && (isempty(strip(lines[line_idx])) || startswith(strip(lines[line_idx]), "#"))
            line_idx += 1
        end
        
        # Lire le nombre de variables
        if line_idx <= length(lines)
            num_variables = parse(Int, strip(lines[line_idx]))
            line_idx += 1
        end
        
        # Ignorer les lignes vides et commentaires
        while line_idx <= length(lines) && (isempty(strip(lines[line_idx])) || startswith(strip(lines[line_idx]), "#"))
            line_idx += 1
        end
        
        # Lire les domaines des variables
        while line_idx <= length(lines) && !isempty(strip(lines[line_idx])) && !startswith(strip(lines[line_idx]), "#")
            parts = split(strip(lines[line_idx]))
            if length(parts) >= 3
                var_id = parse(Int, parts[1])
                min_val = parse(Int, parts[2])
                max_val = parse(Int, parts[3])
                push!(domains, (var_id, min_val, max_val))
                domain_size = max(domain_size, max_val)
            end
            line_idx += 1
        end
        
        # Ignorer les lignes vides et commentaires
        while line_idx <= length(lines) && (isempty(strip(lines[line_idx])) || startswith(strip(lines[line_idx]), "#"))
            line_idx += 1
        end
        
        # Lire le nombre de contraintes
        if line_idx <= length(lines)
            num_constraints = parse(Int, strip(lines[line_idx]))
            line_idx += 1
        end
        
        # Ignorer les lignes vides et commentaires
        while line_idx <= length(lines) && (isempty(strip(lines[line_idx])) || startswith(strip(lines[line_idx]), "#"))
            line_idx += 1
        end
        
        # Lire les contraintes
        while line_idx <= length(lines) && !isempty(strip(lines[line_idx]))
            line = strip(lines[line_idx])
            if !startswith(line, "#")
                parts = split(line)
                if length(parts) >= 2
                    var1 = parse(Int, parts[1])
                    var2 = parse(Int, parts[2])
                    
                    # Parser les paires de valeurs autorisées
                    allowed_pairs = Tuple{Int, Int}[]
                    for i in 3:length(parts)
                        pair_str = parts[i]
                        if startswith(pair_str, "(") && endswith(pair_str, ")")
                            pair_str = pair_str[2:end-1]  # Enlever les parenthèses
                            pair_parts = split(pair_str, ",")
                            if length(pair_parts) == 2
                                val1 = parse(Int, pair_parts[1])
                                val2 = parse(Int, pair_parts[2])
                                push!(allowed_pairs, (val1, val2))
                            end
                        end
                    end
                    
                    if !isempty(allowed_pairs)
                        push!(constraints, (var1, var2, allowed_pairs))
                    end
                end
            end
            line_idx += 1
        end
        
        return CSPInstance(name, num_variables, domain_size, num_constraints, domains, constraints)
    end
end
# Out:
# parse_csp_instance (generic function with 1 method)

# %% [markdown]
# ## Résolution CSP avec Gurobi et JuMP

# %%
function verify_csp_solution(instance::CSPInstance, solution::Dict{Int, Int})::Bool
    """
    Vérifie qu'une solution satisfait toutes les contraintes CSP.
    """
    for (var1, var2, allowed_pairs) in instance.constraints
        val1 = solution[var1]
        val2 = solution[var2]
        if !((val1, val2) in allowed_pairs)
            return false
        end
    end
    return true
end
# Out:
# verify_csp_solution (generic function with 1 method)

# %%
# Solveur CSP avec Gurobi - Trouve toutes les solutions
function solve_csp_instance(instance::CSPInstance; max_solutions::Int=2000)::CSPSolution
    """
    Résout une instance CSP en utilisant Gurobi et JuMP pour trouver TOUTES les solutions.
    Version optimisée utilisant une approche hybride efficace.
    """
    println("=== Résolution de l'instance: ", instance.name)
    
    all_solutions = Dict{Int, Int}[]
    total_solve_time = 0.0
    total_nodes = 0
    max_gap = 0.0
    
    # Créer le modèle JuMP avec Gurobi (UNE SEULE FOIS)
    model = Model(Gurobi.Optimizer)
    
    # Variables binaires pour chaque assignation possible
    # x[var, val] = 1 si la variable var prend la valeur val
    @variable(model, x[0:instance.num_variables-1, 1:instance.domain_size], Bin)
    
    # Contraintes : chaque variable doit prendre exactement une valeur
    for var in 0:instance.num_variables-1
        @constraint(model, sum(x[var, val] for val in 1:instance.domain_size) == 1)
    end
    
    # Contraintes : respecter les contraintes CSP
    for (var1, var2, allowed_pairs) in instance.constraints
        # Créer une contrainte pour chaque paire non autorisée
        forbidden_pairs = []
        for val1 in 1:instance.domain_size
            for val2 in 1:instance.domain_size
                if !((val1, val2) in allowed_pairs)
                    push!(forbidden_pairs, (val1, val2))
                end
            end
        end
        
        # Interdire les paires non autorisées
        for (val1, val2) in forbidden_pairs
            @constraint(model, x[var1, val1] + x[var2, val2] <= 1)
        end
    end
    
    # Objectif : maximiser le nombre de variables assignées (toujours égal au nombre de variables)
    @objective(model, Max, sum(x[var, val] for var in 0:instance.num_variables-1, val in 1:instance.domain_size))
    
    # Configuration Gurobi optimisée
    set_optimizer_attribute(model, "OutputFlag", 1)  # Afficher les informations de progression
    set_optimizer_attribute(model, "TimeLimit", 300)  # 5 minutes max
    set_optimizer_attribute(model, "MIPGap", 0.0)     # Solution exacte
    
    # Configuration pour trouver plusieurs solutions
    set_optimizer_attribute(model, "PoolSearchMode", 1)  # Mode 1: trouve plusieurs solutions optimales
    set_optimizer_attribute(model, "PoolSolutions", max_solutions)  # Nombre maximum de solutions à stocker
    
    println("Configuration optimisée:")
    println("  - Mode de recherche: Multiple solutions optimales")
    println("  - Nombre maximum de solutions: ", max_solutions)
    println("  - Temps limite: 300 secondes")
    
    # Résoudre (UNE SEULE FOIS)
    println("\\nDébut de la résolution...")
    optimize!(model)
    
    # Vérifier le statut
    status = termination_status(model)
    println("Statut de résolution: ", status)
    
    if status == MOI.OPTIMAL || status == MOI.LOCALLY_SOLVED || status == MOI.TIME_LIMIT
        # Extraire la solution optimale trouvée
        println("Extraction de la solution optimale...")
        
        try
            solution = Dict{Int, Int}()
            for var in 0:instance.num_variables-1
                for val in 1:instance.domain_size
                    if value(x[var, val]) > 0.5
                        solution[var] = val
                        break
                    end
                end
            end
            
            if !isempty(solution)
                push!(all_solutions, solution)
                println("Solution optimale extraite: ", solution)
                
                # Vérifier la solution
                if verify_csp_solution(instance, solution)
                    println("✓ Solution optimale vérifiée!")
                else
                    println("✗ Erreur dans la solution optimale!")
                end
            end
        catch e
            println("Erreur lors de l'extraction de la solution optimale: ", e)
        end
        
        # Pour trouver toutes les solutions, utiliser une approche différente
        # Créer un nouveau modèle avec contraintes d'exclusion
        println("\\nRecherche des solutions supplémentaires...")
        
        iteration = 0
        max_iterations = min(max_solutions * 2, 2000)
        
        while length(all_solutions) < max_solutions && iteration < max_iterations
            iteration += 1
            
            # Créer un nouveau modèle pour cette itération
            model_iter = Model(Gurobi.Optimizer)
            
            # Variables binaires
            @variable(model_iter, x_iter[0:instance.num_variables-1, 1:instance.domain_size], Bin)
            
            # Contraintes : chaque variable doit prendre exactement une valeur
            for var in 0:instance.num_variables-1
                @constraint(model_iter, sum(x_iter[var, val] for val in 1:instance.domain_size) == 1)
            end
            
            # Contraintes : respecter les contraintes CSP
            for (var1, var2, allowed_pairs) in instance.constraints
                forbidden_pairs = []
                for val1 in 1:instance.domain_size
                    for val2 in 1:instance.domain_size
                        if !((val1, val2) in allowed_pairs)
                            push!(forbidden_pairs, (val1, val2))
                        end
                    end
                end
                
                for (val1, val2) in forbidden_pairs
                    @constraint(model_iter, x_iter[var1, val1] + x_iter[var2, val2] <= 1)
                end
            end
            
            # Contraintes d'exclusion : interdire les solutions déjà trouvées
            for existing_solution in all_solutions
                exclusion_terms = []
                for var in 0:instance.num_variables-1
                    assigned_value = existing_solution[var]
                    push!(exclusion_terms, x_iter[var, assigned_value])
                end
                @constraint(model_iter, sum(exclusion_terms) <= instance.num_variables - 1)
            end
            
            # Objectif
            @objective(model_iter, Max, sum(x_iter[var, val] for var in 0:instance.num_variables-1, val in 1:instance.domain_size))
            
            # Configuration rapide
            set_optimizer_attribute(model_iter, "OutputFlag", 0)
            set_optimizer_attribute(model_iter, "TimeLimit", 10)
            set_optimizer_attribute(model_iter, "MIPGap", 0.0)
            
            # Résoudre
            optimize!(model_iter)
            
            status_iter = termination_status(model_iter)
            
            if status_iter == MOI.OPTIMAL || status_iter == MOI.LOCALLY_SOLVED
                # Extraire la nouvelle solution
                new_solution = Dict{Int, Int}()
                for var in 0:instance.num_variables-1
                    for val in 1:instance.domain_size
                        if value(x_iter[var, val]) > 0.5
                            new_solution[var] = val
                            break
                        end
                    end
                end
                
                # Vérifier que c'est une nouvelle solution
                is_new = true
                for existing_solution in all_solutions
                    if new_solution == existing_solution
                        is_new = false
                        break
                    end
                end
                
                if is_new
                    push!(all_solutions, new_solution)
                    println("Solution ", length(all_solutions), " trouvée: ", new_solution)
                    
                    # Vérifier la solution
                    if verify_csp_solution(instance, new_solution)
                        println("✓ Solution ", length(all_solutions), " vérifiée!")
                    else
                        println("✗ Erreur dans la solution ", length(all_solutions), "!")
                    end
                else
                    println("Solution dupliquée trouvée, arrêt de la recherche")
                    break
                end
            else
                println("Aucune nouvelle solution trouvée (status: ", status_iter, ")")
                break
            end
        end
        
        println("Recherche terminée après ", iteration, " itérations")
    else
        println("Aucune solution trouvée (status: ", status, ")")
    end
    
    # Récupérer les paramètres de résolution
    total_solve_time = try
        solve_time(model)
    catch
        0.0
    end
    
    total_nodes = try
        node_count(model)
    catch
        0
    end
    
    max_gap = try
        relative_gap(model)
    catch
        0.0
    end
    
    println("\\n=== Résumé de la recherche de toutes les solutions (OPTIMISÉE CORRIGÉE) ===")
    println("Solutions trouvées: ", length(all_solutions))
    println("Temps total de résolution: ", round(total_solve_time, digits=4), " secondes")
    println("Nombre total de nœuds explorés: ", total_nodes)
    println("Gap relatif maximum: ", round(max_gap, digits=6))
    
    return CSPSolution(instance.name, instance.num_variables, instance.domain_size, all_solutions, total_solve_time, total_nodes, max_gap)
end
# Out:
# solve_csp_instance (generic function with 1 method)

# %%
# Fonction d'écriture des solutions au format .sol
function write_csp_solution(solution::CSPSolution, filename::String)
    """
    Écrit la solution CSP dans un fichier au format .sol avec les paramètres de résolution.
    """
    open(filename, "w") do file
        println(file, "# Solution for ", solution.instance_name)
        println(file, "# Variables: ", solution.num_variables, ", Domain size: ", solution.domain_size)
        println(file, "# Number of solutions found: ", length(solution.solutions))
        println(file, "")
        println(file, "# Resolution parameters:")
        println(file, "# Gurobi time: ", round(solution.solve_time, digits=4), " seconds")
        println(file, "# Number of nodes: ", solution.num_nodes)
        println(file, "# Relative gap: ", round(solution.gap, digits=6))
        println(file, "")
        
        for (i, sol) in enumerate(solution.solutions)
            println(file, "# Solution ", i)
            var_assignments = []
            for var in 0:solution.num_variables-1
                value = sol[var]
                push!(var_assignments, "$(var)=$(value)")
            end
            println(file, join(var_assignments, " "))
            println(file, "")
        end
    end
    println("Solution sauvegardée dans: ", filename)
end
# Out:
# write_csp_solution (generic function with 1 method)

# %%
# Fonction principale de résolution CSP
function solve_csp_file(instance_name::String; 
                        instances_dir::String="../instances/instances", 
                        solutions_dir::String="../solutions/solutions")
    """
    Méthode principale pour résoudre une instance CSP.
    Charge l'instance, résout avec Gurobi et sauvegarde la solution.
    """
    println("="^60)
    println("RÉSOLUTION D'INSTANCE CSP AVEC GUROBI")
    println("="^60)
    
    # Chemin vers l'instance
    instance_path = joinpath(instances_dir, instance_name)
    if !isfile(instance_path)
        println("Erreur: Fichier d'instance non trouvé: ", instance_path)
        return nothing
    end
    
    # Charger l'instance
    println("\\n1. Chargement de l'instance...")
    instance = parse_csp_instance(instance_path)
    
    # Afficher les détails de l'instance
    println("\\n2. Analyse de l'instance...")
    print_csp_instance_details(instance)
    
    # Résoudre l'instance
    println("\\n3. Résolution...")
    solution = solve_csp_instance(instance)
    
    # Sauvegarder la solution
    println("\\n4. Sauvegarde de la solution...")
    solution_filename = replace(instance_name, ".csp" => "_gb.sol")
    solution_path = joinpath(solutions_dir, solution_filename)
    
    # Créer le répertoire s'il n'existe pas
    mkpath(dirname(solution_path))
    
    write_csp_solution(solution, solution_path)
    
    # Résumé final
    println("\\n" * "="^60)
    println("RÉSUMÉ DE LA RÉSOLUTION")
    println("="^60)
    println("Instance: ", instance.name)
    println("Variables: ", instance.num_variables)
    println("Domaine: 1 à ", instance.domain_size)
    println("Contraintes: ", instance.num_constraints)
    println("Solutions trouvées: ", length(solution.solutions))
    println("Temps de résolution: ", round(solution.solve_time, digits=4), " secondes")
    println("Nœuds explorés: ", solution.num_nodes)
    println("Gap relatif: ", round(solution.gap, digits=6))
    println("Fichier de solution: ", solution_path)
    
    return solution
end

function print_csp_instance_details(instance::CSPInstance)
    """
    Affiche les détails d'une instance CSP.
    """
    println("=== Détails de l'instance CSP ===")
    println("Nom: ", instance.name)
    println("Nombre de variables: ", instance.num_variables)
    println("Taille du domaine: ", instance.domain_size)
    println("Nombre de contraintes: ", instance.num_constraints)
    
    # Calculer les statistiques
    total_allowed_pairs = sum(length(pairs) for (_, _, pairs) in instance.constraints)
    avg_allowed_pairs = total_allowed_pairs / length(instance.constraints)
    
    println("Nombre total de paires autorisées: ", total_allowed_pairs)
    println("Nombre moyen de paires par contrainte: ", round(avg_allowed_pairs, digits=2))
    
    # Afficher quelques contraintes
    println("\\nPremières contraintes:")
    for (i, (var1, var2, pairs)) in enumerate(instance.constraints[1:min(3, length(instance.constraints))])
        println("  Contrainte ", i, ": var", var1, " et var", var2, " (", length(pairs), " paires autorisées)")
    end
    
    if length(instance.constraints) > 3
        println("  ... et ", length(instance.constraints) - 3, " autres contraintes")
    end
end
# Out:
# print_csp_instance_details (generic function with 1 method)

# %% [markdown]
# ## Résolution des instances de intances/instances

# %%
# Charger l'instance equality_example.csp
instance_path = "../instances/instances/equality_example.csp"
solution_path = "../solutions/solutions/equality_example_gb.sol"
instance = parse_csp_instance(instance_path)

# Résoudre avec la fonction corrigée
solution = solve_csp_instance(instance)

write_csp_solution(solution, solution_path)

println("Nombre de solutions trouvées: ", length(solution.solutions))
for (i, sol) in enumerate(solution.solutions)
    println("Solution ", i, ": ", sol)
end
# Out:
# === Résolution de l'instance: equality_example.csp
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 1
# Set parameter PoolSolutions to value 2000
# Configuration optimisée:
#   - Mode de recherche: Multiple solutions optimales
#   - Nombre maximum de solutions: 2000
#   - Temps limite: 300 secondes
# \nDébut de la résolution...
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 1
# Set parameter PoolSolutions to value 2000
# Set parameter TimeLimit to value 300
# Set parameter OutputFlag to value 1
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 8840HS w/ Radeon 780M Graphics, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  300
# MIPGap  0
# PoolSolutions  2000
# PoolSearchMode  1
#
# Optimize a model with 28 rows, 12 columns and 60 nonzeros
# Model fingerprint: 0xfaa75049
# Variable types: 0 continuous, 12 integer (12 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 4.0000000
# Presolve removed 28 rows and 12 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 16 available processors)
#
# Solution count 1: 4
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 4.000000000000e+00, best bound 4.000000000000e+00, gap 0.0000%
#
# User-callback calls 459, time in user-callback 0.00 sec
# Statut de résolution: OPTIMAL
# Extraction de la solution optimale...
# Solution optimale extraite: Dict(0 => 3, 2 => 3, 3 => 3, 1 => 3)
# ✓ Solution optimale vérifiée!
# \nRecherche des solutions supplémentaires...
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 2 trouvée: Dict(0 => 1, 2 => 1, 3 => 1, 1 => 1)
# ✓ Solution 2 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 3 trouvée: Dict(0 => 2, 2 => 2, 3 => 2, 1 => 2)
# ✓ Solution 3 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Aucune nouvelle solution trouvée (status: INFEASIBLE_OR_UNBOUNDED)
# Recherche terminée après 3 itérations
# \n=== Résumé de la recherche de toutes les solutions (OPTIMISÉE CORRIGÉE) ===
# Solutions trouvées: 3
# Temps total de résolution: 0.015 secondes
# Nombre total de nœuds explorés: 0
# Gap relatif maximum: 0.0
# Solution sauvegardée dans: ../solutions/solutions/equality_example_gb.sol
# Nombre de solutions trouvées: 3
# Solution 1: Dict(0 => 3, 2 => 3, 3 => 3, 1 => 3)
# Solution 2: Dict(0 => 1, 2 => 1, 3 => 1, 1 => 1)
# Solution 3: Dict(0 => 2, 2 => 2, 3 => 2, 1 => 2)

# %%
# boucle de résolution sur toutes les instances du dossier instances/instances
for instance_name in readdir("../instances/instances")
    println("Résolution de l'instance: ", instance_name)
    solve_csp_file(instance_name)
end
# Out:
# Résolution de l'instance: equality_example.csp
# ============================================================
# RÉSOLUTION D'INSTANCE CSP AVEC GUROBI
# ============================================================
# \n1. Chargement de l'instance...
# \n2. Analyse de l'instance...
# === Détails de l'instance CSP ===
# Nom: equality_example.csp
# Nombre de variables: 4
# Taille du domaine: 3
# Nombre de contraintes: 4
# Nombre total de paires autorisées: 12
# Nombre moyen de paires par contrainte: 3.0
# \nPremières contraintes:
#   Contrainte 1: var2 et var3 (3 paires autorisées)
#   Contrainte 2: var0 et var1 (3 paires autorisées)
#   Contrainte 3: var1 et var3 (3 paires autorisées)
#   ... et 1 autres contraintes
# \n3. Résolution...
# === Résolution de l'instance: equality_example.csp
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 1
# Set parameter PoolSolutions to value 2000
# Configuration optimisée:
#   - Mode de recherche: Multiple solutions optimales
#   - Nombre maximum de solutions: 2000
#   - Temps limite: 300 secondes
# \nDébut de la résolution...
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 1
# Set parameter PoolSolutions to value 2000
# Set parameter TimeLimit to value 300
# Set parameter OutputFlag to value 1
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 8840HS w/ Radeon 780M Graphics, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  300
# MIPGap  0
# PoolSolutions  2000
# PoolSearchMode  1
#
# Optimize a model with 28 rows, 12 columns and 60 nonzeros
# Model fingerprint: 0xfaa75049
# Variable types: 0 continuous, 12 integer (12 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 4.0000000
# Presolve removed 28 rows and 12 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 16 available processors)
#
# Solution count 1: 4
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 4.000000000000e+00, best bound 4.000000000000e+00, gap 0.0000%
#
# User-callback calls 459, time in user-callback 0.00 sec
# Statut de résolution: OPTIMAL
# Extraction de la solution optimale...
# Solution optimale extraite: Dict(0 => 3, 2 => 3, 3 => 3, 1 => 3)
# ✓ Solution optimale vérifiée!
# \nRecherche des solutions supplémentaires...
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 2 trouvée: Dict(0 => 1, 2 => 1, 3 => 1, 1 => 1)
# ✓ Solution 2 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 3 trouvée: Dict(0 => 2, 2 => 2, 3 => 2, 1 => 2)
# ✓ Solution 3 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Aucune nouvelle solution trouvée (status: INFEASIBLE_OR_UNBOUNDED)
# Recherche terminée après 3 itérations
# \n=== Résumé de la recherche de toutes les solutions (OPTIMISÉE CORRIGÉE) ===
# Solutions trouvées: 3
# Temps total de résolution: 0.0 secondes
# Nombre total de nœuds explorés: 0
# Gap relatif maximum: 0.0
# \n4. Sauvegarde de la solution...
# Solution sauvegardée dans: ../solutions/solutions\equality_example_gb.sol
# \n============================================================
# RÉSUMÉ DE LA RÉSOLUTION
# ============================================================
# Instance: equality_example.csp
# Variables: 4
# Domaine: 1 à 3
# Contraintes: 4
# Solutions trouvées: 3
# Temps de résolution: 0.0 secondes
# Nœuds explorés: 0
# Gap relatif: 0.0
# Fichier de solution: ../solutions/solutions\equality_example_gb.sol
# Résolution de l'instance: example_inequality.csp
# ============================================================
# RÉSOLUTION D'INSTANCE CSP AVEC GUROBI
# ============================================================
# \n1. Chargement de l'instance...
# \n2. Analyse de l'instance...
# === Détails de l'instance CSP ===
# Nom: example_inequality.csp
# Nombre de variables: 4
# Taille du domaine: 3
# Nombre de contraintes: 6
# Nombre total de paires autorisées: 36
# Nombre moyen de paires par contrainte: 6.0
# \nPremières contraintes:
#   Contrainte 1: var2 et var3 (6 paires autorisées)
#   Contrainte 2: var0 et var1 (6 paires autorisées)
#   Contrainte 3: var1 et var3 (6 paires autorisées)
#   ... et 3 autres contraintes
# \n3. Résolution...
# === Résolution de l'instance: example_inequality.csp
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 1
# Set parameter PoolSolutions to value 2000
# Configuration optimisée:
#   - Mode de recherche: Multiple solutions optimales
#   - Nombre maximum de solutions: 2000
#   - Temps limite: 300 secondes
# \nDébut de la résolution...
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 1
# Set parameter PoolSolutions to value 2000
# Set parameter TimeLimit to value 300
# Set parameter OutputFlag to value 1
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 8840HS w/ Radeon 780M Graphics, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  300
# MIPGap  0
# PoolSolutions  2000
# PoolSearchMode  1
#
# Optimize a model with 22 rows, 12 columns and 48 nonzeros
# Model fingerprint: 0xf2390ac9
# Variable types: 0 continuous, 12 integer (12 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 15 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 7 rows, 12 columns, 24 nonzeros
# Variable types: 0 continuous, 12 integer (12 binary)
#
# Root relaxation: infeasible, 8 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 infeasible    0               - infeasible      -     -    0s
#
# Explored 1 nodes (8 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 0
# No other solutions better than -1e+100
#
# Model is infeasible or unbounded
# Best objective -, best bound -, gap -
#
# User-callback calls 207, time in user-callback 0.00 sec
# Statut de résolution: INFEASIBLE_OR_UNBOUNDED
# Aucune solution trouvée (status: INFEASIBLE_OR_UNBOUNDED)
# \n=== Résumé de la recherche de toutes les solutions (OPTIMISÉE CORRIGÉE) ===
# Solutions trouvées: 0
# Temps total de résolution: 0.006 secondes
# Nombre total de nœuds explorés: 1
# Gap relatif maximum: 0.0
# \n4. Sauvegarde de la solution...
# Solution sauvegardée dans: ../solutions/solutions\example_inequality_gb.sol
# \n============================================================
# RÉSUMÉ DE LA RÉSOLUTION
# ============================================================
# Instance: example_inequality.csp
# Variables: 4
# Domaine: 1 à 3
# Contraintes: 6
# Solutions trouvées: 0
# Temps de résolution: 0.006 secondes
# Nœuds explorés: 1
# Gap relatif: 0.0
# Fichier de solution: ../solutions/solutions\example_inequality_gb.sol
# Résolution de l'instance: example_random.csp
# ============================================================
# RÉSOLUTION D'INSTANCE CSP AVEC GUROBI
# ============================================================
# \n1. Chargement de l'instance...
# \n2. Analyse de l'instance...
# === Détails de l'instance CSP ===
# Nom: example_random.csp
# Nombre de variables: 4
# Taille du domaine: 3
# Nombre de contraintes: 6
# Nombre total de paires autorisées: 36
# Nombre moyen de paires par contrainte: 6.0
# \nPremières contraintes:
#   Contrainte 1: var2 et var3 (6 paires autorisées)
#   Contrainte 2: var0 et var1 (6 paires autorisées)
#   Contrainte 3: var1 et var3 (6 paires autorisées)
#   ... et 3 autres contraintes
# \n3. Résolution...
# === Résolution de l'instance: example_random.csp
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 1
# Set parameter PoolSolutions to value 2000
# Configuration optimisée:
#   - Mode de recherche: Multiple solutions optimales
#   - Nombre maximum de solutions: 2000
#   - Temps limite: 300 secondes
# \nDébut de la résolution...
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 1
# Set parameter PoolSolutions to value 2000
# Set parameter TimeLimit to value 300
# Set parameter OutputFlag to value 1
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 8840HS w/ Radeon 780M Graphics, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  300
# MIPGap  0
# PoolSolutions  2000
# PoolSearchMode  1
#
# Optimize a model with 22 rows, 12 columns and 48 nonzeros
# Model fingerprint: 0x2bd8d948
# Variable types: 0 continuous, 12 integer (12 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 4.0000000
# Presolve removed 22 rows and 12 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 16 available processors)
#
# Solution count 1: 4
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 4.000000000000e+00, best bound 4.000000000000e+00, gap 0.0000%
#
# User-callback calls 262, time in user-callback 0.00 sec
# Statut de résolution: OPTIMAL
# Extraction de la solution optimale...
# Solution optimale extraite: Dict(0 => 1, 2 => 2, 3 => 1, 1 => 2)
# ✓ Solution optimale vérifiée!
# \nRecherche des solutions supplémentaires...
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 2 trouvée: Dict(0 => 1, 2 => 2, 3 => 1, 1 => 1)
# ✓ Solution 2 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 3 trouvée: Dict(0 => 3, 2 => 2, 3 => 2, 1 => 1)
# ✓ Solution 3 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 4 trouvée: Dict(0 => 1, 2 => 2, 3 => 2, 1 => 1)
# ✓ Solution 4 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 5 trouvée: Dict(0 => 1, 2 => 2, 3 => 2, 1 => 2)
# ✓ Solution 5 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 6 trouvée: Dict(0 => 1, 2 => 3, 3 => 1, 1 => 1)
# ✓ Solution 6 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 7 trouvée: Dict(0 => 3, 2 => 2, 3 => 2, 1 => 2)
# ✓ Solution 7 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Aucune nouvelle solution trouvée (status: INFEASIBLE_OR_UNBOUNDED)
# Recherche terminée après 7 itérations
# \n=== Résumé de la recherche de toutes les solutions (OPTIMISÉE CORRIGÉE) ===
# Solutions trouvées: 7
# Temps total de résolution: 0.0 secondes
# Nombre total de nœuds explorés: 0
# Gap relatif maximum: 0.0
# \n4. Sauvegarde de la solution...
# Solution sauvegardée dans: ../solutions/solutions\example_random_gb.sol
# \n============================================================
# RÉSUMÉ DE LA RÉSOLUTION
# ============================================================
# Instance: example_random.csp
# Variables: 4
# Domaine: 1 à 3
# Contraintes: 6
# Solutions trouvées: 7
# Temps de résolution: 0.0 secondes
# Nœuds explorés: 0
# Gap relatif: 0.0
# Fichier de solution: ../solutions/solutions\example_random_gb.sol
# Résolution de l'instance: example_sum.csp
# ============================================================
# RÉSOLUTION D'INSTANCE CSP AVEC GUROBI
# ============================================================
# \n1. Chargement de l'instance...
# \n2. Analyse de l'instance...
# === Détails de l'instance CSP ===
# Nom: example_sum.csp
# Nombre de variables: 4
# Taille du domaine: 3
# Nombre de contraintes: 6
# Nombre total de paires autorisées: 12
# Nombre moyen de paires par contrainte: 2.0
# \nPremières contraintes:
#   Contrainte 1: var2 et var3 (2 paires autorisées)
#   Contrainte 2: var0 et var1 (2 paires autorisées)
#   Contrainte 3: var1 et var3 (2 paires autorisées)
#   ... et 3 autres contraintes
# \n3. Résolution...
# === Résolution de l'instance: example_sum.csp
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 1
# Set parameter PoolSolutions to value 2000
# Configuration optimisée:
#   - Mode de recherche: Multiple solutions optimales
#   - Nombre maximum de solutions: 2000
#   - Temps limite: 300 secondes
# \nDébut de la résolution...
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 1
# Set parameter PoolSolutions to value 2000
# Set parameter TimeLimit to value 300
# Set parameter OutputFlag to value 1
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 8840HS w/ Radeon 780M Graphics, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  300
# MIPGap  0
# PoolSolutions  2000
# PoolSearchMode  1
#
# Optimize a model with 46 rows, 12 columns and 96 nonzeros
# Model fingerprint: 0xecd73da1
# Variable types: 0 continuous, 12 integer (12 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 44 rows and 11 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 16 available processors)
#
# Solution count 0
#
# Model is infeasible or unbounded
# Best objective -, best bound -, gap -
#
# User-callback calls 151, time in user-callback 0.00 sec
# Statut de résolution: INFEASIBLE_OR_UNBOUNDED
# Aucune solution trouvée (status: INFEASIBLE_OR_UNBOUNDED)
# \n=== Résumé de la recherche de toutes les solutions (OPTIMISÉE CORRIGÉE) ===
# Solutions trouvées: 0
# Temps total de résolution: 0.001 secondes
# Nombre total de nœuds explorés: 0
# Gap relatif maximum: 0.0
# \n4. Sauvegarde de la solution...
# Solution sauvegardée dans: ../solutions/solutions\example_sum_gb.sol
# \n============================================================
# RÉSUMÉ DE LA RÉSOLUTION
# ============================================================
# Instance: example_sum.csp
# Variables: 4
# Domaine: 1 à 3
# Contraintes: 6
# Solutions trouvées: 0
# Temps de résolution: 0.001 secondes
# Nœuds explorés: 0
# Gap relatif: 0.0
# Fichier de solution: ../solutions/solutions\example_sum_gb.sol
# Résolution de l'instance: greater_than_example.csp
# ============================================================
# RÉSOLUTION D'INSTANCE CSP AVEC GUROBI
# ============================================================
# \n1. Chargement de l'instance...
# \n2. Analyse de l'instance...
# === Détails de l'instance CSP ===
# Nom: greater_than_example.csp
# Nombre de variables: 4
# Taille du domaine: 3
# Nombre de contraintes: 4
# Nombre total de paires autorisées: 12
# Nombre moyen de paires par contrainte: 3.0
# \nPremières contraintes:
#   Contrainte 1: var2 et var3 (3 paires autorisées)
#   Contrainte 2: var0 et var1 (3 paires autorisées)
#   Contrainte 3: var1 et var3 (3 paires autorisées)
#   ... et 1 autres contraintes
# \n3. Résolution...
# === Résolution de l'instance: greater_than_example.csp
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 1
# Set parameter PoolSolutions to value 2000
# Configuration optimisée:
#   - Mode de recherche: Multiple solutions optimales
#   - Nombre maximum de solutions: 2000
#   - Temps limite: 300 secondes
# \nDébut de la résolution...
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 1
# Set parameter PoolSolutions to value 2000
# Set parameter TimeLimit to value 300
# Set parameter OutputFlag to value 1
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 8840HS w/ Radeon 780M Graphics, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  300
# MIPGap  0
# PoolSolutions  2000
# PoolSearchMode  1
#
# Optimize a model with 28 rows, 12 columns and 60 nonzeros
# Model fingerprint: 0xb0abdc7b
# Variable types: 0 continuous, 12 integer (12 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 4.0000000
# Presolve removed 28 rows and 12 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 16 available processors)
#
# Solution count 1: 4
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 4.000000000000e+00, best bound 4.000000000000e+00, gap 0.0000%
#
# User-callback calls 217, time in user-callback 0.00 sec
# Statut de résolution: OPTIMAL
# Extraction de la solution optimale...
# Solution optimale extraite: Dict(0 => 3, 2 => 3, 3 => 1, 1 => 2)
# ✓ Solution optimale vérifiée!
# \nRecherche des solutions supplémentaires...
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 2 trouvée: Dict(0 => 3, 2 => 2, 3 => 1, 1 => 2)
# ✓ Solution 2 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Aucune nouvelle solution trouvée (status: INFEASIBLE_OR_UNBOUNDED)
# Recherche terminée après 2 itérations
# \n=== Résumé de la recherche de toutes les solutions (OPTIMISÉE CORRIGÉE) ===
# Solutions trouvées: 2
# Temps total de résolution: 0.0 secondes
# Nombre total de nœuds explorés: 0
# Gap relatif maximum: 0.0
# \n4. Sauvegarde de la solution...
# Solution sauvegardée dans: ../solutions/solutions\greater_than_example_gb.sol
# \n============================================================
# RÉSUMÉ DE LA RÉSOLUTION
# ============================================================
# Instance: greater_than_example.csp
# Variables: 4
# Domaine: 1 à 3
# Contraintes: 4
# Solutions trouvées: 2
# Temps de résolution: 0.0 secondes
# Nœuds explorés: 0
# Gap relatif: 0.0
# Fichier de solution: ../solutions/solutions\greater_than_example_gb.sol
# Résolution de l'instance: inequality_example.csp
# ============================================================
# RÉSOLUTION D'INSTANCE CSP AVEC GUROBI
# ============================================================
# \n1. Chargement de l'instance...
# \n2. Analyse de l'instance...
# === Détails de l'instance CSP ===
# Nom: inequality_example.csp
# Nombre de variables: 4
# Taille du domaine: 3
# Nombre de contraintes: 4
# Nombre total de paires autorisées: 24
# Nombre moyen de paires par contrainte: 6.0
# \nPremières contraintes:
#   Contrainte 1: var2 et var3 (6 paires autorisées)
#   Contrainte 2: var0 et var1 (6 paires autorisées)
#   Contrainte 3: var1 et var3 (6 paires autorisées)
#   ... et 1 autres contraintes
# \n3. Résolution...
# === Résolution de l'instance: inequality_example.csp
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 1
# Set parameter PoolSolutions to value 2000
# Configuration optimisée:
#   - Mode de recherche: Multiple solutions optimales
#   - Nombre maximum de solutions: 2000
#   - Temps limite: 300 secondes
# \nDébut de la résolution...
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 1
# Set parameter PoolSolutions to value 2000
# Set parameter TimeLimit to value 300
# Set parameter OutputFlag to value 1
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 8840HS w/ Radeon 780M Graphics, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  300
# MIPGap  0
# PoolSolutions  2000
# PoolSearchMode  1
#
# Optimize a model with 16 rows, 12 columns and 36 nonzeros
# Model fingerprint: 0xf0ba3170
# Variable types: 0 continuous, 12 integer (12 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 4.0000000
# Presolve removed 10 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 6 rows, 9 columns, 18 nonzeros
# Variable types: 0 continuous, 9 integer (9 binary)
#
# Root relaxation: objective 4.000000e+00, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0         4.00000    4.00000  0.00%     -    0s
#
# Optimal solution found at node 0 - now completing solution pool...
#
#     Nodes    |    Current Node    |      Pool Obj. Bounds     |     Work
#              |                    |   Worst                   |
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0               -    4.00000      -     -    0s
#      0     0          -    0               -    4.00000      -     -    0s
#      0     0     cutoff    0               -    4.00000      -     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 4: 4 4 4 4
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 4.000000000000e+00, best bound 4.000000000000e+00, gap 0.0000%
#
# User-callback calls 382, time in user-callback 0.00 sec
# Statut de résolution: OPTIMAL
# Extraction de la solution optimale...
# Solution optimale extraite: Dict(0 => 3, 2 => 1, 3 => 2, 1 => 1)
# ✓ Solution optimale vérifiée!
# \nRecherche des solutions supplémentaires...
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 2 trouvée: Dict(0 => 3, 2 => 3, 3 => 2, 1 => 1)
# ✓ Solution 2 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 3 trouvée: Dict(0 => 3, 2 => 2, 3 => 1, 1 => 2)
# ✓ Solution 3 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 4 trouvée: Dict(0 => 3, 2 => 3, 3 => 1, 1 => 2)
# ✓ Solution 4 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 5 trouvée: Dict(0 => 1, 2 => 2, 3 => 3, 1 => 2)
# ✓ Solution 5 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 6 trouvée: Dict(0 => 1, 2 => 1, 3 => 3, 1 => 2)
# ✓ Solution 6 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 7 trouvée: Dict(0 => 2, 2 => 2, 3 => 1, 1 => 3)
# ✓ Solution 7 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 8 trouvée: Dict(0 => 2, 2 => 3, 3 => 1, 1 => 3)
# ✓ Solution 8 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 9 trouvée: Dict(0 => 1, 2 => 3, 3 => 2, 1 => 3)
# ✓ Solution 9 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 10 trouvée: Dict(0 => 2, 2 => 1, 3 => 3, 1 => 1)
# ✓ Solution 10 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 11 trouvée: Dict(0 => 1, 2 => 1, 3 => 2, 1 => 3)
# ✓ Solution 11 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 12 trouvée: Dict(0 => 2, 2 => 2, 3 => 3, 1 => 1)
# ✓ Solution 12 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Aucune nouvelle solution trouvée (status: INFEASIBLE_OR_UNBOUNDED)
# Recherche terminée après 12 itérations
# \n=== Résumé de la recherche de toutes les solutions (OPTIMISÉE CORRIGÉE) ===
# Solutions trouvées: 12
# Temps total de résolution: 0.006 secondes
# Nombre total de nœuds explorés: 1
# Gap relatif maximum: 0.0
# \n4. Sauvegarde de la solution...
# Solution sauvegardée dans: ../solutions/solutions\inequality_example_gb.sol
# \n============================================================
# RÉSUMÉ DE LA RÉSOLUTION
# ============================================================
# Instance: inequality_example.csp
# Variables: 4
# Domaine: 1 à 3
# Contraintes: 4
# Solutions trouvées: 12
# Temps de résolution: 0.006 secondes
# Nœuds explorés: 1
# Gap relatif: 0.0
# Fichier de solution: ../solutions/solutions\inequality_example_gb.sol
# Résolution de l'instance: large_dense.csp
# ============================================================
# RÉSOLUTION D'INSTANCE CSP AVEC GUROBI
# ============================================================
# \n1. Chargement de l'instance...
# \n2. Analyse de l'instance...
# === Détails de l'instance CSP ===
# Nom: large_dense.csp
# Nombre de variables: 8
# Taille du domaine: 4
# Nombre de contraintes: 16
# Nombre total de paires autorisées: 96
# Nombre moyen de paires par contrainte: 6.0
# \nPremières contraintes:
#   Contrainte 1: var3 et var6 (6 paires autorisées)
#   Contrainte 2: var0 et var4 (6 paires autorisées)
#   Contrainte 3: var0 et var1 (6 paires autorisées)
#   ... et 13 autres contraintes
# \n3. Résolution...
# === Résolution de l'instance: large_dense.csp
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 1
# Set parameter PoolSolutions to value 2000
# Configuration optimisée:
#   - Mode de recherche: Multiple solutions optimales
#   - Nombre maximum de solutions: 2000
#   - Temps limite: 300 secondes
# \nDébut de la résolution...
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 1
# Set parameter PoolSolutions to value 2000
# Set parameter TimeLimit to value 300
# Set parameter OutputFlag to value 1
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 8840HS w/ Radeon 780M Graphics, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  300
# MIPGap  0
# PoolSolutions  2000
# PoolSearchMode  1
#
# Optimize a model with 168 rows, 32 columns and 352 nonzeros
# Model fingerprint: 0x414a9982
# Variable types: 0 continuous, 32 integer (32 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 143 rows and 25 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 16 available processors)
#
# Solution count 0
#
# Model is infeasible or unbounded
# Best objective -, best bound -, gap -
#
# User-callback calls 112, time in user-callback 0.00 sec
# Statut de résolution: INFEASIBLE_OR_UNBOUNDED
# Aucune solution trouvée (status: INFEASIBLE_OR_UNBOUNDED)
# \n=== Résumé de la recherche de toutes les solutions (OPTIMISÉE CORRIGÉE) ===
# Solutions trouvées: 0
# Temps total de résolution: 0.0 secondes
# Nombre total de nœuds explorés: 0
# Gap relatif maximum: 0.0
# \n4. Sauvegarde de la solution...
# Solution sauvegardée dans: ../solutions/solutions\large_dense_gb.sol
# \n============================================================
# RÉSUMÉ DE LA RÉSOLUTION
# ============================================================
# Instance: large_dense.csp
# Variables: 8
# Domaine: 1 à 4
# Contraintes: 16
# Solutions trouvées: 0
# Temps de résolution: 0.0 secondes
# Nœuds explorés: 0
# Gap relatif: 0.0
# Fichier de solution: ../solutions/solutions\large_dense_gb.sol
# Résolution de l'instance: large_sparse.csp
# ============================================================
# RÉSOLUTION D'INSTANCE CSP AVEC GUROBI
# ============================================================
# \n1. Chargement de l'instance...
# \n2. Analyse de l'instance...
# === Détails de l'instance CSP ===
# Nom: large_sparse.csp
# Nombre de variables: 8
# Taille du domaine: 4
# Nombre de contraintes: 12
# Nombre total de paires autorisées: 60
# Nombre moyen de paires par contrainte: 5.0
# \nPremières contraintes:
#   Contrainte 1: var3 et var6 (5 paires autorisées)
#   Contrainte 2: var0 et var4 (5 paires autorisées)
#   Contrainte 3: var0 et var1 (5 paires autorisées)
#   ... et 9 autres contraintes
# \n3. Résolution...
# === Résolution de l'instance: large_sparse.csp
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 1
# Set parameter PoolSolutions to value 2000
# Configuration optimisée:
#   - Mode de recherche: Multiple solutions optimales
#   - Nombre maximum de solutions: 2000
#   - Temps limite: 300 secondes
# \nDébut de la résolution...
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 1
# Set parameter PoolSolutions to value 2000
# Set parameter TimeLimit to value 300
# Set parameter OutputFlag to value 1
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 8840HS w/ Radeon 780M Graphics, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  300
# MIPGap  0
# PoolSolutions  2000
# PoolSearchMode  1
#
# Optimize a model with 140 rows, 32 columns and 296 nonzeros
# Model fingerprint: 0xb54ee2b2
# Variable types: 0 continuous, 32 integer (32 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 112 rows and 19 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 16 available processors)
#
# Solution count 0
#
# Model is infeasible or unbounded
# Best objective -, best bound -, gap -
#
# User-callback calls 98, time in user-callback 0.00 sec
# Statut de résolution: INFEASIBLE_OR_UNBOUNDED
# Aucune solution trouvée (status: INFEASIBLE_OR_UNBOUNDED)
# \n=== Résumé de la recherche de toutes les solutions (OPTIMISÉE CORRIGÉE) ===
# Solutions trouvées: 0
# Temps total de résolution: 0.0 secondes
# Nombre total de nœuds explorés: 0
# Gap relatif maximum: 0.0
# \n4. Sauvegarde de la solution...
# Solution sauvegardée dans: ../solutions/solutions\large_sparse_gb.sol
# \n============================================================
# RÉSUMÉ DE LA RÉSOLUTION
# ============================================================
# Instance: large_sparse.csp
# Variables: 8
# Domaine: 1 à 4
# Contraintes: 12
# Solutions trouvées: 0
# Temps de résolution: 0.0 secondes
# Nœuds explorés: 0
# Gap relatif: 0.0
# Fichier de solution: ../solutions/solutions\large_sparse_gb.sol
# Résolution de l'instance: large_very_sparse.csp
# ============================================================
# RÉSOLUTION D'INSTANCE CSP AVEC GUROBI
# ============================================================
# \n1. Chargement de l'instance...
# \n2. Analyse de l'instance...
# === Détails de l'instance CSP ===
# Nom: large_very_sparse.csp
# Nombre de variables: 10
# Taille du domaine: 3
# Nombre de contraintes: 15
# Nombre total de paires autorisées: 45
# Nombre moyen de paires par contrainte: 3.0
# \nPremières contraintes:
#   Contrainte 1: var6 et var8 (3 paires autorisées)
#   Contrainte 2: var0 et var8 (3 paires autorisées)
#   Contrainte 3: var0 et var2 (3 paires autorisées)
#   ... et 12 autres contraintes
# \n3. Résolution...
# === Résolution de l'instance: large_very_sparse.csp
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 1
# Set parameter PoolSolutions to value 2000
# Configuration optimisée:
#   - Mode de recherche: Multiple solutions optimales
#   - Nombre maximum de solutions: 2000
#   - Temps limite: 300 secondes
# \nDébut de la résolution...
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 1
# Set parameter PoolSolutions to value 2000
# Set parameter TimeLimit to value 300
# Set parameter OutputFlag to value 1
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 8840HS w/ Radeon 780M Graphics, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  300
# MIPGap  0
# PoolSolutions  2000
# PoolSearchMode  1
#
# Optimize a model with 100 rows, 30 columns and 210 nonzeros
# Model fingerprint: 0xbf64ce49
# Variable types: 0 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 71 rows and 14 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 16 available processors)
#
# Solution count 0
#
# Model is infeasible or unbounded
# Best objective -, best bound -, gap -
#
# User-callback calls 98, time in user-callback 0.00 sec
# Statut de résolution: INFEASIBLE_OR_UNBOUNDED
# Aucune solution trouvée (status: INFEASIBLE_OR_UNBOUNDED)
# \n=== Résumé de la recherche de toutes les solutions (OPTIMISÉE CORRIGÉE) ===
# Solutions trouvées: 0
# Temps total de résolution: 0.0 secondes
# Nombre total de nœuds explorés: 0
# Gap relatif maximum: 0.0
# \n4. Sauvegarde de la solution...
# Solution sauvegardée dans: ../solutions/solutions\large_very_sparse_gb.sol
# \n============================================================
# RÉSUMÉ DE LA RÉSOLUTION
# ============================================================
# Instance: large_very_sparse.csp
# Variables: 10
# Domaine: 1 à 3
# Contraintes: 15
# Solutions trouvées: 0
# Temps de résolution: 0.0 secondes
# Nœuds explorés: 0
# Gap relatif: 0.0
# Fichier de solution: ../solutions/solutions\large_very_sparse_gb.sol
# Résolution de l'instance: medium_dense.csp
# ============================================================
# RÉSOLUTION D'INSTANCE CSP AVEC GUROBI
# ============================================================
# \n1. Chargement de l'instance...
# \n2. Analyse de l'instance...
# === Détails de l'instance CSP ===
# Nom: medium_dense.csp
# Nombre de variables: 5
# Taille du domaine: 4
# Nombre de contraintes: 8
# Nombre total de paires autorisées: 64
# Nombre moyen de paires par contrainte: 8.0
# \nPremières contraintes:
#   Contrainte 1: var0 et var2 (8 paires autorisées)
#   Contrainte 2: var0 et var1 (8 paires autorisées)
#   Contrainte 3: var1 et var2 (8 paires autorisées)
#   ... et 5 autres contraintes
# \n3. Résolution...
# === Résolution de l'instance: medium_dense.csp
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 1
# Set parameter PoolSolutions to value 2000
# Configuration optimisée:
#   - Mode de recherche: Multiple solutions optimales
#   - Nombre maximum de solutions: 2000
#   - Temps limite: 300 secondes
# \nDébut de la résolution...
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 1
# Set parameter PoolSolutions to value 2000
# Set parameter TimeLimit to value 300
# Set parameter OutputFlag to value 1
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 8840HS w/ Radeon 780M Graphics, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  300
# MIPGap  0
# PoolSolutions  2000
# PoolSearchMode  1
#
# Optimize a model with 69 rows, 20 columns and 148 nonzeros
# Model fingerprint: 0xee1d6cf1
# Variable types: 0 continuous, 20 integer (20 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 5.0000000
# Presolve removed 69 rows and 20 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 16 available processors)
#
# Solution count 1: 5
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 5.000000000000e+00, best bound 5.000000000000e+00, gap 0.0000%
#
# User-callback calls 354, time in user-callback 0.00 sec
# Statut de résolution: OPTIMAL
# Extraction de la solution optimale...
# Solution optimale extraite: Dict(0 => 1, 4 => 3, 2 => 3, 3 => 3, 1 => 4)
# ✓ Solution optimale vérifiée!
# \nRecherche des solutions supplémentaires...
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 2 trouvée: Dict(0 => 4, 4 => 2, 2 => 1, 3 => 2, 1 => 2)
# ✓ Solution 2 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Aucune nouvelle solution trouvée (status: INFEASIBLE_OR_UNBOUNDED)
# Recherche terminée après 2 itérations
# \n=== Résumé de la recherche de toutes les solutions (OPTIMISÉE CORRIGÉE) ===
# Solutions trouvées: 2
# Temps total de résolution: 0.0 secondes
# Nombre total de nœuds explorés: 0
# Gap relatif maximum: 0.0
# \n4. Sauvegarde de la solution...
# Solution sauvegardée dans: ../solutions/solutions\medium_dense_gb.sol
# \n============================================================
# RÉSUMÉ DE LA RÉSOLUTION
# ============================================================
# Instance: medium_dense.csp
# Variables: 5
# Domaine: 1 à 4
# Contraintes: 8
# Solutions trouvées: 2
# Temps de résolution: 0.0 secondes
# Nœuds explorés: 0
# Gap relatif: 0.0
# Fichier de solution: ../solutions/solutions\medium_dense_gb.sol
# Résolution de l'instance: medium_medium.csp
# ============================================================
# RÉSOLUTION D'INSTANCE CSP AVEC GUROBI
# ============================================================
# \n1. Chargement de l'instance...
# \n2. Analyse de l'instance...
# === Détails de l'instance CSP ===
# Nom: medium_medium.csp
# Nombre de variables: 6
# Taille du domaine: 3
# Nombre de contraintes: 8
# Nombre total de paires autorisées: 32
# Nombre moyen de paires par contrainte: 4.0
# \nPremières contraintes:
#   Contrainte 1: var2 et var4 (4 paires autorisées)
#   Contrainte 2: var0 et var2 (4 paires autorisées)
#   Contrainte 3: var0 et var1 (4 paires autorisées)
#   ... et 5 autres contraintes
# \n3. Résolution...
# === Résolution de l'instance: medium_medium.csp
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 1
# Set parameter PoolSolutions to value 2000
# Configuration optimisée:
#   - Mode de recherche: Multiple solutions optimales
#   - Nombre maximum de solutions: 2000
#   - Temps limite: 300 secondes
# \nDébut de la résolution...
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 1
# Set parameter PoolSolutions to value 2000
# Set parameter TimeLimit to value 300
# Set parameter OutputFlag to value 1
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 8840HS w/ Radeon 780M Graphics, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  300
# MIPGap  0
# PoolSolutions  2000
# PoolSearchMode  1
#
# Optimize a model with 46 rows, 18 columns and 98 nonzeros
# Model fingerprint: 0xe06dfc6a
# Variable types: 0 continuous, 18 integer (18 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 6.0000000
# Presolve removed 46 rows and 18 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 16 available processors)
#
# Solution count 1: 6
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 6.000000000000e+00, best bound 6.000000000000e+00, gap 0.0000%
#
# User-callback calls 232, time in user-callback 0.00 sec
# Statut de résolution: OPTIMAL
# Extraction de la solution optimale...
# Solution optimale extraite: Dict(0 => 1, 4 => 2, 5 => 1, 2 => 2, 3 => 3, 1 => 1)
# ✓ Solution optimale vérifiée!
# \nRecherche des solutions supplémentaires...
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 2 trouvée: Dict(0 => 1, 4 => 2, 5 => 1, 2 => 2, 3 => 3, 1 => 2)
# ✓ Solution 2 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Aucune nouvelle solution trouvée (status: INFEASIBLE_OR_UNBOUNDED)
# Recherche terminée après 2 itérations
# \n=== Résumé de la recherche de toutes les solutions (OPTIMISÉE CORRIGÉE) ===
# Solutions trouvées: 2
# Temps total de résolution: 0.0 secondes
# Nombre total de nœuds explorés: 0
# Gap relatif maximum: 0.0
# \n4. Sauvegarde de la solution...
# Solution sauvegardée dans: ../solutions/solutions\medium_medium_gb.sol
# \n============================================================
# RÉSUMÉ DE LA RÉSOLUTION
# ============================================================
# Instance: medium_medium.csp
# Variables: 6
# Domaine: 1 à 3
# Contraintes: 8
# Solutions trouvées: 2
# Temps de résolution: 0.0 secondes
# Nœuds explorés: 0
# Gap relatif: 0.0
# Fichier de solution: ../solutions/solutions\medium_medium_gb.sol
# Résolution de l'instance: medium_sparse.csp
# ============================================================
# RÉSOLUTION D'INSTANCE CSP AVEC GUROBI
# ============================================================
# \n1. Chargement de l'instance...
# \n2. Analyse de l'instance...
# === Détails de l'instance CSP ===
# Nom: medium_sparse.csp
# Nombre de variables: 5
# Taille du domaine: 4
# Nombre de contraintes: 6
# Nombre total de paires autorisées: 30
# Nombre moyen de paires par contrainte: 5.0
# \nPremières contraintes:
#   Contrainte 1: var0 et var2 (5 paires autorisées)
#   Contrainte 2: var0 et var1 (5 paires autorisées)
#   Contrainte 3: var1 et var2 (5 paires autorisées)
#   ... et 3 autres contraintes
# \n3. Résolution...
# === Résolution de l'instance: medium_sparse.csp
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 1
# Set parameter PoolSolutions to value 2000
# Configuration optimisée:
#   - Mode de recherche: Multiple solutions optimales
#   - Nombre maximum de solutions: 2000
#   - Temps limite: 300 secondes
# \nDébut de la résolution...
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 1
# Set parameter PoolSolutions to value 2000
# Set parameter TimeLimit to value 300
# Set parameter OutputFlag to value 1
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 7 8840HS w/ Radeon 780M Graphics, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  300
# MIPGap  0
# PoolSolutions  2000
# PoolSearchMode  1
#
# Optimize a model with 71 rows, 20 columns and 152 nonzeros
# Model fingerprint: 0x7f696b76
# Variable types: 0 continuous, 20 integer (20 binary)
# Coefficient statistics:
# ...
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 562 trouvée: Dict(5 => 1, 8 => 6, 1 => 3, 0 => 10, 6 => 5, 9 => 9, 3 => 4, 7 => 2, 4 => 8, 2 => 11, 10 => 7)
# ✓ Solution 562 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 563 trouvée: Dict(5 => 1, 8 => 8, 1 => 10, 0 => 4, 6 => 7, 9 => 3, 3 => 11, 7 => 2, 4 => 6, 2 => 5, 10 => 9)
# ✓ Solution 563 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 564 trouvée: Dict(5 => 7, 8 => 9, 1 => 6, 0 => 11, 6 => 10, 9 => 5, 3 => 1, 7 => 2, 4 => 4, 2 => 8, 10 => 3)
# ✓ Solution 564 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 565 trouvée: Dict(5 => 6, 8 => 2, 1 => 8, 0 => 4, 6 => 9, 9 => 11, 3 => 3, 7 => 5, 4 => 10, 2 => 1, 10 => 7)
# ✓ Solution 565 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 566 trouvée: Dict(5 => 5, 8 => 3, 1 => 8, 0 => 6, 6 => 2, 9 => 7, 3 => 4, 7 => 10, 4 => 1, 2 => 11, 10 => 9)
# ✓ Solution 566 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 567 trouvée: Dict(5 => 10, 8 => 9, 1 => 1, 0 => 4, 6 => 3, 9 => 11, 3 => 2, 7 => 5, 4 => 7, 2 => 8, 10 => 6)
# ✓ Solution 567 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 568 trouvée: Dict(5 => 5, 8 => 4, 1 => 3, 0 => 7, 6 => 10, 9 => 6, 3 => 11, 7 => 2, 4 => 9, 2 => 1, 10 => 8)
# ✓ Solution 568 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 569 trouvée: Dict(5 => 6, 8 => 1, 1 => 4, 0 => 8, 6 => 11, 9 => 3, 3 => 7, 7 => 9, 4 => 10, 2 => 2, 10 => 5)
# ✓ Solution 569 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 570 trouvée: Dict(5 => 5, 8 => 6, 1 => 7, 0 => 2, 6 => 3, 9 => 8, 3 => 4, 7 => 11, 4 => 9, 2 => 10, 10 => 1)
# ✓ Solution 570 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 571 trouvée: Dict(5 => 6, 8 => 5, 1 => 4, 0 => 2, 6 => 1, 9 => 8, 3 => 9, 7 => 3, 4 => 11, 2 => 7, 10 => 10)
# ✓ Solution 571 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 572 trouvée: Dict(5 => 11, 8 => 4, 1 => 5, 0 => 10, 6 => 1, 9 => 2, 3 => 6, 7 => 7, 4 => 9, 2 => 3, 10 => 8)
# ✓ Solution 572 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 573 trouvée: Dict(5 => 3, 8 => 4, 1 => 5, 0 => 2, 6 => 1, 9 => 9, 3 => 6, 7 => 8, 4 => 10, 2 => 11, 10 => 7)
# ✓ Solution 573 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 574 trouvée: Dict(5 => 3, 8 => 4, 1 => 8, 0 => 6, 6 => 11, 9 => 2, 3 => 7, 7 => 9, 4 => 1, 2 => 5, 10 => 10)
# ✓ Solution 574 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 575 trouvée: Dict(5 => 3, 8 => 5, 1 => 11, 0 => 9, 6 => 1, 9 => 2, 3 => 7, 7 => 8, 4 => 10, 2 => 4, 10 => 6)
# ✓ Solution 575 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 576 trouvée: Dict(5 => 9, 8 => 8, 1 => 7, 0 => 3, 6 => 11, 9 => 1, 3 => 4, 7 => 6, 4 => 2, 2 => 10, 10 => 5)
# ✓ Solution 576 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 577 trouvée: Dict(5 => 9, 8 => 8, 1 => 7, 0 => 5, 6 => 1, 9 => 11, 3 => 6, 7 => 4, 4 => 2, 2 => 10, 10 => 3)
# ✓ Solution 577 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 578 trouvée: Dict(5 => 9, 8 => 10, 1 => 7, 0 => 1, 6 => 4, 9 => 8, 3 => 3, 7 => 2, 4 => 11, 2 => 5, 10 => 6)
# ✓ Solution 578 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 579 trouvée: Dict(5 => 6, 8 => 10, 1 => 8, 0 => 5, 6 => 9, 9 => 4, 3 => 11, 7 => 1, 4 => 3, 2 => 2, 10 => 7)
# ✓ Solution 579 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 580 trouvée: Dict(5 => 1, 8 => 2, 1 => 10, 0 => 3, 6 => 8, 9 => 9, 3 => 4, 7 => 5, 4 => 11, 2 => 6, 10 => 7)
# ✓ Solution 580 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 581 trouvée: Dict(5 => 9, 8 => 10, 1 => 2, 0 => 7, 6 => 11, 9 => 4, 3 => 3, 7 => 5, 4 => 1, 2 => 8, 10 => 6)
# ✓ Solution 581 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 582 trouvée: Dict(5 => 11, 8 => 7, 1 => 1, 0 => 5, 6 => 2, 9 => 3, 3 => 4, 7 => 10, 4 => 6, 2 => 9, 10 => 8)
# ✓ Solution 582 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 583 trouvée: Dict(5 => 8, 8 => 6, 1 => 9, 0 => 7, 6 => 10, 9 => 11, 3 => 3, 7 => 4, 4 => 5, 2 => 1, 10 => 2)
# ✓ Solution 583 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 584 trouvée: Dict(5 => 11, 8 => 4, 1 => 3, 0 => 9, 6 => 5, 9 => 1, 3 => 10, 7 => 8, 4 => 2, 2 => 6, 10 => 7)
# ✓ Solution 584 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 585 trouvée: Dict(5 => 10, 8 => 9, 1 => 1, 0 => 8, 6 => 3, 9 => 7, 3 => 2, 7 => 11, 4 => 6, 2 => 5, 10 => 4)
# ✓ Solution 585 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 586 trouvée: Dict(5 => 9, 8 => 11, 1 => 7, 0 => 2, 6 => 5, 9 => 4, 3 => 3, 7 => 8, 4 => 1, 2 => 10, 10 => 6)
# ✓ Solution 586 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 587 trouvée: Dict(5 => 11, 8 => 1, 1 => 6, 0 => 3, 6 => 8, 9 => 9, 3 => 7, 7 => 4, 4 => 2, 2 => 10, 10 => 5)
# ✓ Solution 587 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 588 trouvée: Dict(5 => 10, 8 => 11, 1 => 2, 0 => 6, 6 => 1, 9 => 7, 3 => 5, 7 => 3, 4 => 8, 2 => 9, 10 => 4)
# ✓ Solution 588 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 589 trouvée: Dict(5 => 5, 8 => 4, 1 => 3, 0 => 8, 6 => 1, 9 => 10, 3 => 6, 7 => 11, 4 => 2, 2 => 9, 10 => 7)
# ✓ Solution 589 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 590 trouvée: Dict(5 => 11, 8 => 9, 1 => 10, 0 => 8, 6 => 3, 9 => 4, 3 => 1, 7 => 7, 4 => 6, 2 => 5, 10 => 2)
# ✓ Solution 590 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 591 trouvée: Dict(5 => 6, 8 => 1, 1 => 4, 0 => 2, 6 => 10, 9 => 9, 3 => 11, 7 => 5, 4 => 3, 2 => 8, 10 => 7)
# ✓ Solution 591 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 592 trouvée: Dict(5 => 6, 8 => 1, 1 => 3, 0 => 5, 6 => 9, 9 => 7, 3 => 10, 7 => 11, 4 => 4, 2 => 8, 10 => 2)
# ✓ Solution 592 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 593 trouvée: Dict(5 => 6, 8 => 11, 1 => 7, 0 => 4, 6 => 8, 9 => 9, 3 => 10, 7 => 3, 4 => 2, 2 => 1, 10 => 5)
# ✓ Solution 593 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 594 trouvée: Dict(5 => 3, 8 => 4, 1 => 9, 0 => 5, 6 => 1, 9 => 2, 3 => 6, 7 => 8, 4 => 10, 2 => 11, 10 => 7)
# ✓ Solution 594 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 595 trouvée: Dict(5 => 8, 8 => 6, 1 => 1, 0 => 9, 6 => 2, 9 => 11, 3 => 7, 7 => 4, 4 => 3, 2 => 10, 10 => 5)
# ✓ Solution 595 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 596 trouvée: Dict(5 => 10, 8 => 6, 1 => 1, 0 => 7, 6 => 2, 9 => 8, 3 => 9, 7 => 11, 4 => 5, 2 => 4, 10 => 3)
# ✓ Solution 596 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 597 trouvée: Dict(5 => 4, 8 => 6, 1 => 11, 0 => 7, 6 => 10, 9 => 2, 3 => 3, 7 => 1, 4 => 9, 2 => 8, 10 => 5)
# ✓ Solution 597 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 598 trouvée: Dict(5 => 7, 8 => 3, 1 => 2, 0 => 8, 6 => 10, 9 => 9, 3 => 1, 7 => 6, 4 => 11, 2 => 5, 10 => 4)
# ✓ Solution 598 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 599 trouvée: Dict(5 => 7, 8 => 3, 1 => 9, 0 => 6, 6 => 10, 9 => 5, 3 => 4, 7 => 1, 4 => 11, 2 => 2, 10 => 8)
# ✓ Solution 599 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 600 trouvée: Dict(5 => 10, 8 => 3, 1 => 7, 0 => 4, 6 => 6, 9 => 1, 3 => 2, 7 => 9, 4 => 5, 2 => 11, 10 => 8)
# ✓ Solution 600 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 601 trouvée: Dict(5 => 8, 8 => 7, 1 => 9, 0 => 5, 6 => 3, 9 => 11, 3 => 4, 7 => 1, 4 => 10, 2 => 2, 10 => 6)
# ✓ Solution 601 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 602 trouvée: Dict(5 => 2, 8 => 7, 1 => 8, 0 => 6, 6 => 11, 9 => 5, 3 => 1, 7 => 9, 4 => 4, 2 => 10, 10 => 3)
# ✓ Solution 602 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 603 trouvée: Dict(5 => 1, 8 => 3, 1 => 7, 0 => 4, 6 => 11, 9 => 6, 3 => 2, 7 => 9, 4 => 5, 2 => 10, 10 => 8)
# ✓ Solution 603 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 604 trouvée: Dict(5 => 1, 8 => 9, 1 => 3, 0 => 5, 6 => 10, 9 => 4, 3 => 6, 7 => 7, 4 => 11, 2 => 8, 10 => 2)
# ✓ Solution 604 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 605 trouvée: Dict(5 => 7, 8 => 3, 1 => 8, 0 => 5, 6 => 10, 9 => 6, 3 => 4, 7 => 1, 4 => 2, 2 => 11, 10 => 9)
# ✓ Solution 605 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution
# Excessive output truncated after 524288 bytes.
# 606 trouvée: Dict(5 => 9, 8 => 2, 1 => 3, 0 => 8, 6 => 11, 9 => 6, 3 => 4, 7 => 5, 4 => 7, 2 => 1, 10 => 10)
# ✓ Solution 606 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 607 trouvée: Dict(5 => 5, 8 => 9, 1 => 4, 0 => 11, 6 => 8, 9 => 6, 3 => 10, 7 => 1, 4 => 3, 2 => 7, 10 => 2)
# ✓ Solution 607 vérifiée!
# Set parameter Username
# Set parameter LicenseID to value 2709359
# Academic license - for non-commercial use only - expires 2026-09-16
# Set parameter MIPGap to value 0
# Set parameter TimeLimit to value 10
# Solution 608 trouvée: Dict(5 =>
